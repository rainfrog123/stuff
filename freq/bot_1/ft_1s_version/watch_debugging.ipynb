# %%
input_dict = {'max_open_trades': inf, 'stake_currency': '', 'stake_amount': 100, 'tradable_balance_ratio': 0.99, 'fiat_display_currency': 'USD', 'dry_run': True, 'dry_run_wallet': 10000, 'cancel_open_orders_on_exit': False, 'trading_mode': <TradingMode.FUTURES: 'futures'>, 'margin_mode': 'isolated', 'unfilledtimeout': {'entry': 10, 'exit': 10, 'exit_timeout_count': 0, 'unit': 'minutes'}, 'entry_pricing': {'price_side': 'same', 'use_order_book': True, 'order_book_top': 1, 'price_last_balance': 0.0, 'check_depth_of_market': {...}}, 'exit_pricing': {'price_side': 'same', 'use_order_book': True, 'order_book_top': 1}, 'exchange': {'name': 'binance', 'ccxt_config': {...}, 'key': '', 'secret': '', 'ccxt_async_config': {}, 'pair_whitelist': [...], 'pair_blacklist': [...], 'password': '', 'apiKey': '', ...}, ...}

# %%
import json

def beautify_dict(input_dict):
    beautified_json = json.dumps(input_dict, indent=4)
    return beautified_json


# Beautify the dictionary
beautified_dict = beautify_dict(input_dict)

# Print the beautified dictionary
print(beautified_dict)

# %%
pri
