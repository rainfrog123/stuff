# %%
import pandas as pd

# Load the Parquet file into a pandas DataFrame
file_path = '/allah/freqtrade/THE_USDT_preprocessed.parquet'
df = pd.read_parquet(file_path)

# Display the first few rows of the DataFrame
# Out:
#                        date    open    high     low   close   volume date_15m  \
# 0 2024-12-21 19:00:00+00:00  1.2159  1.2183  1.2149  1.2151  14011.2      NaT
# 1 2024-12-21 19:01:00+00:00  1.2150  1.2150  1.2093  1.2110  62792.0      NaT
# 2 2024-12-21 19:02:00+00:00  1.2109  1.2178  1.2105  1.2164  73733.5      NaT
# 3 2024-12-21 19:03:00+00:00  1.2161  1.2178  1.2128  1.2160  34521.4      NaT
# 4 2024-12-21 19:04:00+00:00  1.2162  1.2166  1.2123  1.2141  14748.0      NaT
#
#    open_15m  high_15m  low_15m  ...  high_5m  low_5m  close_5m  volume_5m  \
# 0       NaN       NaN      NaN  ...      NaN     NaN       NaN        NaN
# 1       NaN       NaN      NaN  ...      NaN     NaN       NaN        NaN
# 2       NaN       NaN      NaN  ...      NaN     NaN       NaN        NaN
# 3       NaN       NaN      NaN  ...      NaN     NaN       NaN        NaN
# 4       NaN       NaN      NaN  ...   1.2183  1.2093    1.2141   199806.1
#
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
# Ensure the 'date' column is parsed as a datetime
df['date'] = pd.to_datetime(df['date'])

# Filter rows where the date matches the specific value
filtered_df = df[df['date'] == '2024-12-22 02:17:00']
filtered_df
# Display the filtered rows
# Out:
#                          date    open    high     low   close   volume  \
# 437 2024-12-22 02:17:00+00:00  1.1979  1.1991  1.1963  1.1974  12624.7
#
#                      date_15m  open_15m  high_15m  low_15m  close_15m  \
# 437 2024-12-22 02:00:00+00:00    1.2002    1.2048   1.1952     1.1968
#
#      volume_15m  tema_15m  trend_15m                   date_1h  open_1h  \
# 437    257656.7    1.1869       -1.0 2024-12-22 01:00:00+00:00    1.212
#
#      high_1h  low_1h  close_1h  volume_1h   tema_1h  trend_1h  \
# 437   1.2247  1.1827    1.2002  1668142.5  1.237051      -1.0
#
#                      date_30m  open_30m  high_30m  low_30m  close_30m  \
# 437 2024-12-22 01:30:00+00:00    1.2073    1.2077   1.1827     1.2002
#
#      volume_30m  tema_30m  trend_30m                   date_3m  open_3m  \
# 437    969002.9  1.215857       -1.0 2024-12-22 02:15:00+00:00   1.1968
#
#      high_3m  low_3m  close_3m  volume_3m   tema_3m  trend_3m  \
# ...

# %%
filtered_df
# Out:
#                          date    open   high     low   close   volume  \
# 438 2024-12-22 02:18:00+00:00  1.1973  1.198  1.1932  1.1935  14866.6
#
#                      date_15m  open_15m  high_15m  low_15m  ...  high_5m  \
# 438 2024-12-22 02:00:00+00:00    1.2002    1.2048   1.1952  ...   1.2018
#
#      low_5m  close_5m  volume_5m   tema_5m  trend_5m      tema  trend  \
# 438  1.1952    1.1968    71619.8  1.203462      -1.0  1.195591     -1
#
#           atr  atr_percentage
# 438  0.003436        0.287927
#
# [1 rows x 50 columns]

# %%
import pandas as pd

# Load JSON file
file_path = '/allah/stuff/freq/userdir/user_data/backtest_results/backtest-result-2024-12-25_05-17-31.json'

import json
with open(file_path) as f:
    data = json.load(f)

# %%
data
# Out:
# {'strategy': {'MultiTimeframeTEMAAgreement': {'trades': [{'pair': 'THE/USDT:USDT',
#      'stake_amount': 99.999456,
#      'max_stake_amount': 7499.9592,
#      'amount': 6260.4,
#      'open_date': '2024-12-22 00:09:00+00:00',
#      'close_date': '2024-12-22 00:09:00+00:00',
#      'open_rate': 1.198,
#      'close_rate': 1.2012,
#      'fee_open': 0.0005,
#      'fee_close': 0.0005,
#      'trade_duration': 0,
#      'profit_ratio': -0.2755718426826101,
#      'profit_abs': -27.54325584,
#      'exit_reason': 'liquidation',
#      'initial_stop_loss_abs': 1.2131,
#      'initial_stop_loss_ratio': -0.95,
#      'stop_loss_abs': 1.2048,
#      'stop_loss_ratio': -0.42829752169322366,
#      'min_rate': 1.198,
#      'max_rate': 1.2022,
#      'is_open': False,
#      'enter_tag': 'aligned_down',
#      'leverage': 75.0,
#      'is_short': True,
#      'open_timestamp': 1734826140000,
#      'close_timestamp': 1734826140000,
#      'orders': [{'amount': 6260.4,
# ...
