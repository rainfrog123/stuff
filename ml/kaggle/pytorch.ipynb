# %%
import torch

# Create a tensor with random data
x = torch.rand(5, 3)  # 5 rows and 3 columns
print(x)

# Move the tensor to GPU if available
if torch.cuda.is_available():
    x = x.to('cuda')
# Out:
# tensor([[0.6374, 0.5217, 0.4399],
#         [0.5218, 0.1351, 0.9580],
#         [0.5680, 0.3144, 0.7394],
#         [0.6208, 0.2315, 0.3184],
#         [0.8245, 0.8840, 0.1225]])

# %%
import torch

# Matrices
a = torch.tensor([[1, 2], [3, 4]])
b = torch.tensor([[5, 6], [7, 8]])

# Matrix multiplication
c = torch.mm(a, b)

# Print result
print("Resulting Matrix c:")
print(c)

# Breakdown of each element in c
print("\nStep-by-step:")
print("c[0,0] = (1*5) + (2*7) =", 1*5 + 2*7)  # c[0,0] = 19
print("c[0,1] = (1*6) + (2*8) =", 1*6 + 2*8)  # c[0,1] = 22
print("c[1,0] = (3*5) + (4*7) =", 3*5 + 4*7)  # c[1,0] = 43
print("c[1,1] = (3*6) + (4*8) =", 3*6 + 4*8)  # c[1,1] = 50
# Out:
# Resulting Matrix c:
# tensor([[19, 22],
#         [43, 50]])
#
# Step-by-step:
# c[0,0] = (1*5) + (2*7) = 19
# c[0,1] = (1*6) + (2*8) = 22
# c[1,0] = (3*5) + (4*7) = 43
# c[1,1] = (3*6) + (4*8) = 50
