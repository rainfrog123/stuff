# %%
import requests
import json

# Function to construct the proxy URL dynamically based on session parameters
def construct_proxy_url(username, password, session_id, sticky_time, country):
    """
    Constructs the Smartproxy URL dynamically based on session parameters.
    """
    # Construct the proxy link based on the session
    # proxy_url = f"socks5://{username}-session-{session_id}-sessionduration-{sticky_time}-country-{country}:{password}@gate.smartproxy.com:7000"
    proxy_url = f"socks5://{username}-session-{session_id}-sessionduration-{sticky_time}-country-{country}:{password}@gate.visitxiangtan.com:7000"
    return proxy_url

# Function to generate multiple proxies and retrieve their associated IPs
def get_proxies_and_ips(username, password, sticky_time, country, num_sessions):
    """
    Generates multiple proxy sessions and retrieves IP addresses for each session.
    
    Args:
    - username: The Smartproxy username.
    - password: The Smartproxy password.
    - sticky_time: The session duration in seconds.
    - country: The country code for the proxy.
    - num_sessions: The number of proxy sessions to generate.
    
    Returns:
    - A list of IP addresses retrieved from the proxy sessions.
    """
    proxy_ips = []
    url = 'https://ip.smartproxy.com/json'
    
    for session_id in range(20, 20 + num_sessions + 1):
        proxy_url = construct_proxy_url(username, password, session_id, sticky_time, country)
        try:
            # Make the request using the generated proxy
            result = requests.get(url, proxies={
                'http': proxy_url,
                'https': proxy_url
            })
            if result.status_code == 200:
                formatted_response = json.loads(result.text)
                ip = formatted_response.get('proxy', {}).get('ip', 'IP not found')
                country_code = formatted_response.get('country', {}).get('name', 'Country code not found')
                proxy_ips.append(ip)
                # Print IP first, followed by the respective proxy link
                print(f"Session {session_id} - IP: {ip}, Proxy: {proxy_url}")
                print(f"Country: {country_code}")
            else:
                print(f"Failed to retrieve IP for session {session_id}. Status code: {result.status_code}")
        
        except Exception as e:
            print(f"Error in session {session_id}: {str(e)}")
    
    return proxy_ips

# Example usage
username = 'user-sp797yej9h'  # Your Smartproxy username
password = 'n7x6Tsj73Kpz_DmRkt'  # Your Smartproxy password
sticky_time = 30  # Set the sticky time (in minutes)
country = 'de'  # Set the country code (e.g., 'cn' for China)
num_sessions = 20  # Number of proxy sessions

# Retrieve proxies and IPs for the specified number of sessions
proxy_ips = get_proxies_and_ips(username, password, sticky_time, country, num_sessions)
print("Retrieved IPs:", proxy_ips)
# Out:
# Session 20 - IP: 77.64.255.84, Proxy: socks5://user-sp797yej9h-session-20-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 21 - IP: 176.3.74.235, Proxy: socks5://user-sp797yej9h-session-21-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 22 - IP: 87.122.31.44, Proxy: socks5://user-sp797yej9h-session-22-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 23 - IP: 77.187.8.253, Proxy: socks5://user-sp797yej9h-session-23-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 24 - IP: 130.185.22.220, Proxy: socks5://user-sp797yej9h-session-24-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 25 - IP: 46.223.163.177, Proxy: socks5://user-sp797yej9h-session-25-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 26 - IP: 77.8.31.249, Proxy: socks5://user-sp797yej9h-session-26-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 27 - IP: 217.85.79.69, Proxy: socks5://user-sp797yej9h-session-27-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 28 - IP: 92.72.55.192, Proxy: socks5://user-sp797yej9h-session-28-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 29 - IP: 149.233.200.202, Proxy: socks5://user-sp797yej9h-session-29-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 30 - IP: 95.91.228.56, Proxy: socks5://user-sp797yej9h-session-30-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 31 - IP: 83.135.187.35, Proxy: socks5://user-sp797yej9h-session-31-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 32 - IP: 88.150.51.167, Proxy: socks5://user-sp797yej9h-session-32-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 33 - IP: 91.97.89.224, Proxy: socks5://user-sp797yej9h-session-33-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 34 - IP: 2.210.36.45, Proxy: socks5://user-sp797yej9h-session-34-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 35 - IP: 77.179.203.24, Proxy: socks5://user-sp797yej9h-session-35-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 36 - IP: 37.201.147.200, Proxy: socks5://user-sp797yej9h-session-36-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 37 - IP: 109.40.240.173, Proxy: socks5://user-sp797yej9h-session-37-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 38 - IP: 37.201.117.13, Proxy: socks5://user-sp797yej9h-session-38-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 39 - IP: 95.90.183.96, Proxy: socks5://user-sp797yej9h-session-39-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 40 - IP: 93.201.237.144, Proxy: socks5://user-sp797yej9h-session-40-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Retrieved IPs: ['77.64.255.84', '176.3.74.235', '87.122.31.44', '77.187.8.253', '130.185.22.220', '46.223.163.177', '77.8.31.249', '217.85.79.69', '92.72.55.192', '149.233.200.202', '95.91.228.56', '83.135.187.35', '88.150.51.167', '91.97.89.224', '2.210.36.45', '77.179.203.24', '37.201.147.200', '109.40.240.173', '37.201.117.13', '95.90.183.96', '93.201.237.144']

# %%
import requests
import json

# Function to construct the proxy URL dynamically based on session parameters
def construct_proxy_url_for_state(username, password, session_id, sticky_time, state):
    """
    Constructs the Smartproxy URL dynamically based on session parameters for U.S. states.
    """
    # Construct the proxy link based on the session
    proxy_url = f"socks5://{username}-session-{session_id}-sessionduration-{sticky_time}-state-{state}:{password}@gate.visitxiangtan.com:7000"
    return proxy_url

# Function to generate multiple proxies and retrieve their associated IPs
def get_proxies_and_ips_for_states(username, password, sticky_time, state, num_sessions):
    """
    Generates multiple proxy sessions for specific U.S. states and retrieves IP addresses for each session.
    
    Args:
    - username: The Smartproxy username.
    - password: The Smartproxy password.
    - sticky_time: The session duration in seconds.
    - state: The state code for the proxy (e.g., "us_california").
    - num_sessions: The number of proxy sessions to generate.
    
    Returns:
    - A list of IP addresses retrieved from the proxy sessions.
    """
    proxy_ips = []
    url = 'https://ip.smartproxy.com/json'
    
    for session_id in range(20, 20 + num_sessions + 1):
        proxy_url = construct_proxy_url_for_state(username, password, session_id, sticky_time, state)
        try:
            # Make the request using the generated proxy
            result = requests.get(url, proxies={
                'http': proxy_url,
                'https': proxy_url
            })
            if result.status_code == 200:
                formatted_response = json.loads(result.text)
                ip = formatted_response.get('proxy', {}).get('ip', 'IP not found')
                country_code = formatted_response.get('country', {}).get('name', 'Country code not found')
                proxy_ips.append(ip)
                # Print IP first, followed by the respective proxy link
                print(f"Session {session_id} - IP: {ip}, Proxy: {proxy_url}")
                print(f"Country/State: {country_code}")
            else:
                print(f"Failed to retrieve IP for session {session_id}. Status code: {result.status_code}")
        
        except Exception as e:
            print(f"Error in session {session_id}: {str(e)}")
    
    return proxy_ips

# Example usage
username = 'user-sp797yej9h'  # Your Smartproxy username
password = 'n7x6Tsj73Kpz_DmRkt'  # Your Smartproxy password
sticky_time = 30  # Set the sticky time (in minutes)
state = 'us_california'  # Set the U.S. state code (e.g., 'us_california' for California)
num_sessions = 20  # Number of proxy sessions

# Retrieve proxies and IPs for the specified number of sessions
proxy_ips = get_proxies_and_ips_for_states(username, password, sticky_time, state, num_sessions)
print("Retrieved IPs:", proxy_ips)
