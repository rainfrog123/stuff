# %%
api_key = '75a4518416e3a6833a28b3b9f46c0733b6ee8d2867db44b5590b400e7d06f6bd853969afa3fa7ff87788df3fa7a854d9fbe8de27eb76736a6d4f13cabdf1839f1971417d95d99f7befb3f5adf3f39f7d'

# %%
import requests
import json  # Import the json library to format the output

url = "https://api.smartproxy.com/v2/subscriptions?api-key=75a4518416e3a6833a28b3b9f46c0733b6ee8d2867db44b5590b400e7d06f6bd853969afa3fa7ff87788df3fa7a854d9fbe8de27eb76736a6d4f13cabdf1839f1971417d95d99f7befb3f5adf3f39f7d"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

# Beautify the JSON response
formatted_response = json.loads(response.text)  # Load the JSON
print(json.dumps(formatted_response, indent=4))  # Pretty-print with indentation
# Out:
# [
#     {
#         "traffic_limit": "0.1",
#         "traffic": "0",
#         "proxy_users_limit": 1,
#         "ip_address_limit": 1,
#         "valid_from": "2024-10-13",
#         "valid_until": "2024-10-16",
#         "service_type": "residential_proxies"
#     }
# ]

# %%
import requests
import json

# Your API key
api_key = '75a4518416e3a6833a28b3b9f46c0733b6ee8d2867db44b5590b400e7d06f6bd853969afa3fa7ff87788df3fa7a854d9fbe8de27eb76736a6d4f13cabdf1839f1971417d95d99f7befb3f5adf3f39f7d'


# URL for getting all endpoints
url = "https://api.smartproxy.com/v1/endpoints"

# Set headers for the API request
headers = {
    "Authorization": f"Bearer {api_key}",
    "accept": "application/json"
}

# Make the request
response = requests.get(url, headers=headers)

# Beautify the JSON response
formatted_response = json.loads(response.text)
print(json.dumps(formatted_response, indent=4))
# Out:
# [
#     {
#         "type": "random",
#         "available_locations": "206",
#         "url": "endpoints/random"
#     },
#     {
#         "type": "sticky",
#         "available_locations": "206",
#         "url": "endpoints/sticky"
#     }
# ]

# %%
import requests
import json

# Your API key (replace with your actual key)
# api_key = "your-api-key-here"

# URL for retrieving sticky (static) proxies
url = "https://api.smartproxy.com/v1/endpoints/sticky"

# Set the headers for the request
headers = {
    "Authorization": f"Bearer {api_key}",
    "accept": "application/json"
}

# Make the request to the Smartproxy API
response = requests.get(url, headers=headers)

# Beautify the JSON response
formatted_response = json.loads(response.text)
print(json.dumps(formatted_response, indent=4))

country_list = [{"location": item['location'], "prefix": item['hostname'].split('.')[0]} for item in formatted_response]
# Out:
# [
#     {
#         "location": "Random",
#         "hostname": "gate.smartproxy.com",
#         "port_range": "10001 - 49999"
#     },
#     {
#         "location": "USA",
#         "hostname": "us.smartproxy.com",
#         "port_range": "10001 - 29999"
#     },
#     {
#         "location": "Canada",
#         "hostname": "ca.smartproxy.com",
#         "port_range": "20001 - 29999"
#     },
#     {
#         "location": "Great Britain",
#         "hostname": "gb.smartproxy.com",
#         "port_range": "30001 - 49999"
#     },
#     {
#         "location": "Germany",
#         "hostname": "de.smartproxy.com",
#         "port_range": "20001 - 29999"
#     },
#     {
#         "location": "France",
#         "hostname": "fr.smartproxy.com",
#         "port_range": "40001 - 49999"
#     },
#     {
#         "location": "Spain",
#         "hostname": "es.smartproxy.com",
#         "port_range": "10001 - 19999"
#     },
#     {
#         "location": "Italy",
#         "hostname": "it.smartproxy.com",
#         "port_range": "20001 - 29999"
#     },
#     {
#         "location": "Sweden",
#         "hostname": "se.smartproxy.com",
#         "port_range": "20001 - 29999"
#     },
#     {
#         "location": "Greece",
#         "hostname": "gr.smartproxy.com",
#         "port_range": "30001 - 39999"
#     },
#     {
#         "location": "Portugal",
#         "hostname": "pt.smartproxy.com",
#         "port_range": "20001 - 29999"
#     },
#     {
#         "location": "Netherlands",
#         "hostname": "nl.smartproxy.com",
#         "port_range": "10001 - 19999"
#     },
#     {
#         "location": "Belgium",
#         "hostname": "be.smartproxy.com",
#         "port_range": "40001 - 49999"
#     },
#     {
#         "location": "Russia",
#         "hostname": "ru.smartproxy.com",
#         "port_range": "40001 - 49999"
#     },
#     {
#         "location": "Ukraine",
#         "hostname": "ua.smartproxy.com",
#         "port_range": "40001 - 49999"
#     },
#     {
#         "location": "Poland",
#         "hostname": "pl.smartproxy.com",
#         "port_range": "20001 - 29999"
#     },
#     {
#         "location": "Israel",
#         "hostname": "il.smartproxy.com",
#         "port_range": "30001 - 39999"
#     },
#     {
#         "location": "Turkey",
#         "hostname": "tr.smartproxy.com",
#         "port_range": "40001 - 49999"
#     },
#     {
#         "location": "Australia",
#         "hostname": "au.smartproxy.com",
#         "port_range": "30001 - 39999"
#     },
#     {
#         "location": "Malaysia",
#         "hostname": "my.smartproxy.com",
#         "port_range": "30001 - 39999"
#     },
#     {
#         "location": "Thailand",
#         "hostname": "th.smartproxy.com",
#         "port_range": "30001 - 39999"
#     },
#     {
#         "location": "South Korea",
#         "hostname": "kr.smartproxy.com",
#         "port_range": "10001 - 19999"
#     },
#     {
#         "location": "Japan",
#         "hostname": "jp.smartproxy.com",
#         "port_range": "30001 - 39999"
#     },
#     {
#         "location": "Philippines",
#         "hostname": "ph.smartproxy.com",
#         "port_range": "40001 - 49999"
#     },
#     {
#         "location": "Singapore",
#         "hostname": "sg.smartproxy.com",
#         "port_range": "10001 - 19999"
#     },
#     {
#         "location": "China",
#         "hostname": "cn.smartproxy.com",
#         "port_range": "30001 - 39999"
#     },
#     {
#         "location": "Hong Kong",
#         "hostname": "hk.smartproxy.com",
#         "port_range": "10001 - 19999"
#     },
#     {
#         "location": "Taiwan",
#         "hostname": "tw.smartproxy.com",
#         "port_range": "20001 - 29999"
#     },
#     {
#         "location": "India",
#         "hostname": "in.smartproxy.com",
#         "port_range": "10001 - 19999"
#     },
#     {
#         "location": "Pakistan",
#         "hostname": "pk.smartproxy.com",
#         "port_range": "10001 - 19999"
#     },
#     {
#         "location": "Iran",
#         "hostname": "ir.smartproxy.com",
#         "port_range": "30001 - 39999"
#     },
#     {
#         "location": "Indonesia",
#         "hostname": "id.smartproxy.com",
#         "port_range": "10001 - 19999"
#     },
#     {
#         "location": "Azerbaijan",
#         "hostname": "az.smartproxy.com",
#         "port_range": "30001 - 39999"
#     },
#     {
#         "location": "Kazakhstan",
#         "hostname": "kz.smartproxy.com",
#         "port_range": "40001 - 49999"
#     },
#     {
#         "location": "UAE",
#         "hostname": "ae.smartproxy.com",
#         "port_range": "20001 - 29999"
#     },
#     {
#         "location": "Mexico",
#         "hostname": "mx.smartproxy.com",
#         "port_range": "20001 - 29999"
#     },
#     {
#         "location": "Brazil",
#         "hostname": "br.smartproxy.com",
#         "port_range": "10001 - 19999"
#     },
#     {
#         "location": "Argentina",
#         "hostname": "ar.smartproxy.com",
#         "port_range": "10001 - 19999"
#     },
#     {
#         "location": "Chile",
#         "hostname": "cl.smartproxy.com",
#         "port_range": "30001 - 39999"
#     },
#     {
#         "location": "Peru",
#         "hostname": "pe.smartproxy.com",
#         "port_range": "40001 - 49999"
#     },
#     {
#         "location": "Ecuador",
#         "hostname": "ec.smartproxy.com",
#         "port_range": "20001 - 29999"
#     },
#     {
#         "location": "Colombia",
#         "hostname": "co.smartproxy.com",
#         "port_range": "30001 - 39999"
#     },
#     {
#         "location": "South Africa",
#         "hostname": "za.smartproxy.com",
#         "port_range": "40001 - 49999"
#     },
#     {
#         "location": "Egypt",
#         "hostname": "eg.smartproxy.com",
#         "port_range": "20001 - 29999"
#     },
#     {
#         "location": "Angola",
#         "hostname": "ao.smartproxy.com",
#         "port_range": "18001 - 18999"
#     },
#     {
#         "location": "Cameroon",
#         "hostname": "cm.smartproxy.com",
#         "port_range": "19001 - 19999"
#     },
#     {
#         "location": "Chad",
#         "hostname": "td.smartproxy.com",
#         "port_range": "11001 - 11999"
#     },
#     {
#         "location": "Benin",
#         "hostname": "bj.smartproxy.com",
#         "port_range": "12001 - 12999"
#     },
#     {
#         "location": "Ethiopia",
#         "hostname": "et.smartproxy.com",
#         "port_range": "13001 - 13999"
#     },
#     {
#         "location": "Djibouti",
#         "hostname": "dj.smartproxy.com",
#         "port_range": "14001 - 14999"
#     },
#     {
#         "location": "Gambia",
#         "hostname": "gm.smartproxy.com",
#         "port_range": "15001 - 15999"
#     },
#     {
#         "location": "Ghana",
#         "hostname": "gh.smartproxy.com",
#         "port_range": "43001 - 43999"
#     },
#     {
#         "location": "Kenya",
#         "hostname": "ke.smartproxy.com",
#         "port_range": "45001 - 45999"
#     },
#     {
#         "location": "Liberia",
#         "hostname": "lr.smartproxy.com",
#         "port_range": "46001 - 46999"
#     },
#     {
#         "location": "Madagascar",
#         "hostname": "mg.smartproxy.com",
#         "port_range": "47001 - 47999"
#     },
#     {
#         "location": "Mali",
#         "hostname": "ml.smartproxy.com",
#         "port_range": "48001 - 48999"
#     },
#     {
#         "location": "Mauritania",
#         "hostname": "mr.smartproxy.com",
#         "port_range": "16001 - 16999"
#     },
#     {
#         "location": "Mauritius",
#         "hostname": "mu.smartproxy.com",
#         "port_range": "17001 - 17999"
#     },
#     {
#         "location": "Morocco",
#         "hostname": "ma.smartproxy.com",
#         "port_range": "40001 - 40999"
#     },
#     {
#         "location": "Mozambique",
#         "hostname": "mz.smartproxy.com",
#         "port_range": "41001 - 41999"
#     },
#     {
#         "location": "Nigeria",
#         "hostname": "ng.smartproxy.com",
#         "port_range": "42001 - 42999"
#     },
#     {
#         "location": "Senegal",
#         "hostname": "sn.smartproxy.com",
#         "port_range": "49001 - 49999"
#     },
#     {
#         "location": "Seychelles",
#         "hostname": "sc.smartproxy.com",
#         "port_range": "10001 - 10999"
#     },
#     {
#         "location": "Zimbabwe",
#         "hostname": "zw.smartproxy.com",
#         "port_range": "11001 - 11999"
#     },
#     {
#         "location": "South Sudan",
#         "hostname": "ss.smartproxy.com",
#         "port_range": "12001 - 12999"
#     },
#     {
#         "location": "Sudan",
#         "hostname": "sd.smartproxy.com",
#         "port_range": "31001 - 31999"
#     },
#     {
#         "location": "Togo",
#         "hostname": "tg.smartproxy.com",
#         "port_range": "32001 - 32999"
#     },
#     {
#         "location": "Tunisia",
#         "hostname": "tn.smartproxy.com",
#         "port_range": "33001 - 33999"
#     },
#     {
#         "location": "Uganda",
#         "hostname": "ug.smartproxy.com",
#         "port_range": "34001 - 34999"
#     },
#     {
#         "location": "Zambia",
#         "hostname": "zm.smartproxy.com",
#         "port_range": "35001 - 35999"
#     },
#     {
#         "location": "Afghanistan",
#         "hostname": "af.smartproxy.com",
#         "port_range": "36001 - 36999"
#     },
#     {
#         "location": "Bahrain",
#         "hostname": "bh.smartproxy.com",
#         "port_range": "37001 - 37999"
#     },
#     {
#         "location": "Bangladesh",
#         "hostname": "bd.smartproxy.com",
#         "port_range": "41001 - 41999"
#     },
#     {
#         "location": "Bhutan",
#         "hostname": "bt.smartproxy.com",
#         "port_range": "45001 - 45999"
#     },
#     {
#         "location": "Myanmar",
#         "hostname": "mm.smartproxy.com",
#         "port_range": "46001 - 46999"
#     },
#     {
#         "location": "Cambodia",
#         "hostname": "kh.smartproxy.com",
#         "port_range": "47001 - 47999"
#     },
#     {
#         "location": "Iraq",
#         "hostname": "iq.smartproxy.com",
#         "port_range": "44001 - 44999"
#     },
#     {
#         "location": "Jordan",
#         "hostname": "jo.smartproxy.com",
#         "port_range": "26001 - 26999"
#     },
#     {
#         "location": "Lebanon",
#         "hostname": "lb.smartproxy.com",
#         "port_range": "27001 - 27999"
#     },
#     {
#         "location": "Maldives",
#         "hostname": "mv.smartproxy.com",
#         "port_range": "28001 - 28999"
#     },
#     {
#         "location": "Mongolia",
#         "hostname": "mn.smartproxy.com",
#         "port_range": "29001 - 29999"
#     },
#     {
#         "location": "Oman",
#         "hostname": "om.smartproxy.com",
#         "port_range": "30001 - 30999"
#     },
#     {
#         "location": "Qatar",
#         "hostname": "qa.smartproxy.com",
#         "port_range": "44001 - 44999"
#     },
#     {
#         "location": "Saudi Arabia",
#         "hostname": "sa.smartproxy.com",
#         "port_range": "45001 - 45999"
#     },
#     {
#         "location": "Turkmenistan",
#         "hostname": "tm.smartproxy.com",
#         "port_range": "47001 - 47999"
#     },
#     {
#         "location": "Uzbekistan",
#         "hostname": "uz.smartproxy.com",
#         "port_range": "48001 - 48999"
#     },
#     {
#         "location": "Yemen",
#         "hostname": "ye.smartproxy.com",
#         "port_range": "49001 - 49999"
#     },
#     {
#         "location": "Albania",
#         "hostname": "al.smartproxy.com",
#         "port_range": "33001 - 33999"
#     },
#     {
#         "location": "Andorra",
#         "hostname": "ad.smartproxy.com",
#         "port_range": "34001 - 34999"
#     },
#     {
#         "location": "Austria",
#         "hostname": "at.smartproxy.com",
#         "port_range": "35001 - 35999"
#     },
#     {
#         "location": "Armenia",
#         "hostname": "am.smartproxy.com",
#         "port_range": "42001 - 42999"
#     },
#     {
#         "location": "Bosnia and Herzegovina",
#         "hostname": "ba.smartproxy.com",
#         "port_range": "37001 - 37999"
#     },
#     {
#         "location": "Bulgaria",
#         "hostname": "bg.smartproxy.com",
#         "port_range": "38001 - 38999"
#     },
#     {
#         "location": "Belarus",
#         "hostname": "by.smartproxy.com",
#         "port_range": "39001 - 39999"
#     },
#     {
#         "location": "Croatia",
#         "hostname": "hr.smartproxy.com",
#         "port_range": "40001 - 40999"
#     },
#     {
#         "location": "Cyprus",
#         "hostname": "cy.smartproxy.com",
#         "port_range": "48001 - 48999"
#     },
#     {
#         "location": "Czech Republic",
#         "hostname": "cz.smartproxy.com",
#         "port_range": "26001 - 26999"
#     },
#     {
#         "location": "Denmark",
#         "hostname": "dk.smartproxy.com",
#         "port_range": "27001 - 27999"
#     },
#     {
#         "location": "Estonia",
#         "hostname": "ee.smartproxy.com",
#         "port_range": "28001 - 28999"
#     },
#     {
#         "location": "Finland",
#         "hostname": "fi.smartproxy.com",
#         "port_range": "41001 - 41999"
#     },
#     {
#         "location": "Georgia",
#         "hostname": "ge.smartproxy.com",
#         "port_range": "43001 - 43999"
#     },
#     {
#         "location": "Hungary",
#         "hostname": "hu.smartproxy.com",
#         "port_range": "43001 - 43999"
#     },
#     {
#         "location": "Iceland",
#         "hostname": "is.smartproxy.com",
#         "port_range": "23001 - 23999"
#     },
#     {
#         "location": "Ireland",
#         "hostname": "ie.smartproxy.com",
#         "port_range": "24001 - 24999"
#     },
#     {
#         "location": "Latvia",
#         "hostname": "lv.smartproxy.com",
#         "port_range": "22001 - 22999"
#     },
#     {
#         "location": "Liechtenstein",
#         "hostname": "li.smartproxy.com",
#         "port_range": "23001 - 23999"
#     },
#     {
#         "location": "Lithuania",
#         "hostname": "lt.smartproxy.com",
#         "port_range": "24001 - 24999"
#     },
#     {
#         "location": "Luxembourg",
#         "hostname": "lu.smartproxy.com",
#         "port_range": "25001 - 25999"
#     },
#     {
#         "location": "Monaco",
#         "hostname": "mc.smartproxy.com",
#         "port_range": "10001 - 10999"
#     },
#     {
#         "location": "Moldova",
#         "hostname": "md.smartproxy.com",
#         "port_range": "11001 - 11999"
#     },
#     {
#         "location": "Montenegro",
#         "hostname": "me.smartproxy.com",
#         "port_range": "12001 - 12999"
#     },
#     {
#         "location": "Norway",
#         "hostname": "no.smartproxy.com",
#         "port_range": "13001 - 13999"
#     },
#     {
#         "location": "Romania",
#         "hostname": "ro.smartproxy.com",
#         "port_range": "13001 - 13999"
#     },
#     {
#         "location": "Serbia",
#         "hostname": "rs.smartproxy.com",
#         "port_range": "14001 - 14999"
#     },
#     {
#         "location": "Slovakia",
#         "hostname": "sk.smartproxy.com",
#         "port_range": "15001 - 15999"
#     },
#     {
#         "location": "Slovenia",
#         "hostname": "si.smartproxy.com",
#         "port_range": "16001 - 16999"
#     },
#     {
#         "location": "Switzerland",
#         "hostname": "ch.smartproxy.com",
#         "port_range": "29001 - 29999"
#     },
#     {
#         "location": "Macedonia",
#         "hostname": "mk.smartproxy.com",
#         "port_range": "30001 - 30999"
#     },
#     {
#         "location": "Bahamas",
#         "hostname": "bs.smartproxy.com",
#         "port_range": "17001 - 17999"
#     },
#     {
#         "location": "Belize",
#         "hostname": "bz.smartproxy.com",
#         "port_range": "18001 - 18999"
#     },
#     {
#         "location": "British Virgin Islands",
#         "hostname": "vg.smartproxy.com",
#         "port_range": "19001 - 19999"
#     },
#     {
#         "location": "Costa Rica",
#         "hostname": "cr.smartproxy.com",
#         "port_range": "31001 - 31999"
#     },
#     {
#         "location": "Cuba",
#         "hostname": "cu.smartproxy.com",
#         "port_range": "32001 - 32999"
#     },
#     {
#         "location": "Dominica",
#         "hostname": "dm.smartproxy.com",
#         "port_range": "17001 - 17999"
#     },
#     {
#         "location": "Haiti",
#         "hostname": "ht.smartproxy.com",
#         "port_range": "18001 - 18999"
#     },
#     {
#         "location": "Honduras",
#         "hostname": "hn.smartproxy.com",
#         "port_range": "19001 - 19999"
#     },
#     {
#         "location": "Jamaica",
#         "hostname": "jm.smartproxy.com",
#         "port_range": "20001 - 20999"
#     },
#     {
#         "location": "Aruba",
#         "hostname": "aw.smartproxy.com",
#         "port_range": "21001 - 21999"
#     },
#     {
#         "location": "Panama",
#         "hostname": "pa.smartproxy.com",
#         "port_range": "20001 - 20999"
#     },
#     {
#         "location": "Puerto Rico",
#         "hostname": "pr.smartproxy.com",
#         "port_range": "21001 - 21999"
#     },
#     {
#         "location": "Trinidad and Tobago",
#         "hostname": "tt.smartproxy.com",
#         "port_range": "22001 - 22999"
#     },
#     {
#         "location": "Fiji",
#         "hostname": "fj.smartproxy.com",
#         "port_range": "38001 - 38999"
#     },
#     {
#         "location": "New Zealand",
#         "hostname": "nz.smartproxy.com",
#         "port_range": "39001 - 39999"
#     },
#     {
#         "location": "Bolivia",
#         "hostname": "bo.smartproxy.com",
#         "port_range": "40001 - 40999"
#     },
#     {
#         "location": "Paraguay",
#         "hostname": "py.smartproxy.com",
#         "port_range": "14001 - 14999"
#     },
#     {
#         "location": "Uruguay",
#         "hostname": "uy.smartproxy.com",
#         "port_range": "15001 - 15999"
#     },
#     {
#         "location": "C\u00f4te d'Ivoire",
#         "hostname": "ci.smartproxy.com",
#         "port_range": "44001 - 44999"
#     },
#     {
#         "location": "Syria",
#         "hostname": "sy.smartproxy.com",
#         "port_range": "20001 - 20999"
#     },
#     {
#         "location": "New York",
#         "hostname": "city.smartproxy.com",
#         "port_range": "21001 - 21049"
#     },
#     {
#         "location": "Los Angeles",
#         "hostname": "city.smartproxy.com",
#         "port_range": "21051 - 21099"
#     },
#     {
#         "location": "Chicago",
#         "hostname": "city.smartproxy.com",
#         "port_range": "21101 - 21149"
#     },
#     {
#         "location": "Houston",
#         "hostname": "city.smartproxy.com",
#         "port_range": "21151 - 21199"
#     },
#     {
#         "location": "Miami",
#         "hostname": "city.smartproxy.com",
#         "port_range": "21201 - 21249"
#     },
#     {
#         "location": "London",
#         "hostname": "city.smartproxy.com",
#         "port_range": "21251 - 21299"
#     },
#     {
#         "location": "Berlin",
#         "hostname": "city.smartproxy.com",
#         "port_range": "21301 - 21349"
#     },
#     {
#         "location": "Moscow",
#         "hostname": "city.smartproxy.com",
#         "port_range": "21351 - 21399"
#     },
#     {
#         "location": "Vietnam",
#         "hostname": "vn.smartproxy.com",
#         "port_range": "46001 - 46999"
#     },
#     {
#         "location": "US",
#         "hostname": "gate.dc.smartproxy.com",
#         "port_range": "20001 - 37960"
#     },
#     {
#         "location": "Malta",
#         "hostname": "mt.smartproxy.com",
#         "port_range": "49001 - 49999"
#     },
#     {
#         "location": "Europe",
#         "hostname": "eu.smartproxy.com",
#         "port_range": "10001 - 49999"
#     },
#     {
#         "location": "Alabama",
#         "hostname": "state.smartproxy.com",
#         "port_range": "17001 - 17099"
#     },
#     {
#         "location": "Alaska",
#         "hostname": "state.smartproxy.com",
#         "port_range": "17101 - 17199"
#     },
#     {
#         "location": "Arizona",
#         "hostname": "state.smartproxy.com",
#         "port_range": "17201 - 17299"
#     },
#     {
#         "location": "Arkansas",
#         "hostname": "state.smartproxy.com",
#         "port_range": "17301 - 17399"
#     },
#     {
#         "location": "California",
#         "hostname": "state.smartproxy.com",
#         "port_range": "10001 - 10999"
#     },
#     {
#         "location": "Colorado",
#         "hostname": "state.smartproxy.com",
#         "port_range": "17401 - 17499"
#     },
#     {
#         "location": "Connecticut",
#         "hostname": "state.smartproxy.com",
#         "port_range": "17501 - 17599"
#     },
#     {
#         "location": "Delaware",
#         "hostname": "state.smartproxy.com",
#         "port_range": "17601 - 17699"
#     },
#     {
#         "location": "Florida",
#         "hostname": "state.smartproxy.com",
#         "port_range": "11001 - 11999"
#     },
#     {
#         "location": "Georgia (US)",
#         "hostname": "state.smartproxy.com",
#         "port_range": "17701 - 17799"
#     },
#     {
#         "location": "Hawaii",
#         "hostname": "state.smartproxy.com",
#         "port_range": "17801 - 17899"
#     },
#     {
#         "location": "Idaho",
#         "hostname": "state.smartproxy.com",
#         "port_range": "17901 - 17999"
#     },
#     {
#         "location": "Illinois",
#         "hostname": "state.smartproxy.com",
#         "port_range": "12001 - 12999"
#     },
#     {
#         "location": "Indiana",
#         "hostname": "state.smartproxy.com",
#         "port_range": "18001 - 18099"
#     },
#     {
#         "location": "Iowa",
#         "hostname": "state.smartproxy.com",
#         "port_range": "18101 - 18199"
#     },
#     {
#         "location": "Kansas",
#         "hostname": "state.smartproxy.com",
#         "port_range": "18201 - 18299"
#     },
#     {
#         "location": "Kentucky",
#         "hostname": "state.smartproxy.com",
#         "port_range": "18301 - 18399"
#     },
#     {
#         "location": "Louisiana",
#         "hostname": "state.smartproxy.com",
#         "port_range": "18401 - 18499"
#     },
#     {
#         "location": "Maine",
#         "hostname": "state.smartproxy.com",
#         "port_range": "18501 - 18599"
#     },
#     {
#         "location": "Maryland",
#         "hostname": "state.smartproxy.com",
#         "port_range": "18601 - 18699"
#     },
#     {
#         "location": "Massachusetts",
#         "hostname": "state.smartproxy.com",
#         "port_range": "18701 - 18799"
#     },
#     {
#         "location": "Michigan",
#         "hostname": "state.smartproxy.com",
#         "port_range": "18801 - 18899"
#     },
#     {
#         "location": "Minnesota",
#         "hostname": "state.smartproxy.com",
#         "port_range": "18901 - 18999"
#     },
#     {
#         "location": "Mississippi",
#         "hostname": "state.smartproxy.com",
#         "port_range": "19001 - 19099"
#     },
#     {
#         "location": "Missouri",
#         "hostname": "state.smartproxy.com",
#         "port_range": "19101 - 19199"
#     },
#     {
#         "location": "Montana",
#         "hostname": "state.smartproxy.com",
#         "port_range": "19201 - 19299"
#     },
#     {
#         "location": "Nebraska",
#         "hostname": "state.smartproxy.com",
#         "port_range": "19301 - 19399"
#     },
#     {
#         "location": "Nevada",
#         "hostname": "state.smartproxy.com",
#         "port_range": "19401 - 19499"
#     },
#     {
#         "location": "New Hampshire",
#         "hostname": "state.smartproxy.com",
#         "port_range": "19501 - 19599"
#     },
#     {
#         "location": "New Jersey",
#         "hostname": "state.smartproxy.com",
#         "port_range": "19601 - 19699"
#     },
#     {
#         "location": "New Mexico",
#         "hostname": "state.smartproxy.com",
#         "port_range": "19701 - 19799"
#     },
#     {
#         "location": "New York",
#         "hostname": "state.smartproxy.com",
#         "port_range": "13001 - 13999"
#     },
#     {
#         "location": "North Carolina",
#         "hostname": "state.smartproxy.com",
#         "port_range": "19801 - 19899"
#     },
#     {
#         "location": "North Dakota",
#         "hostname": "state.smartproxy.com",
#         "port_range": "19901 - 19999"
#     },
#     {
#         "location": "Ohio",
#         "hostname": "state.smartproxy.com",
#         "port_range": "20001 - 20099"
#     },
#     {
#         "location": "Oklahoma",
#         "hostname": "state.smartproxy.com",
#         "port_range": "20101 - 20199"
#     },
#     {
#         "location": "Oregon",
#         "hostname": "state.smartproxy.com",
#         "port_range": "20201 - 20299"
#     },
#     {
#         "location": "Pennsylvania",
#         "hostname": "state.smartproxy.com",
#         "port_range": "20301 - 20399"
#     },
#     {
#         "location": "Rhode Island",
#         "hostname": "state.smartproxy.com",
#         "port_range": "20401 - 20499"
#     },
#     {
#         "location": "South Carolina",
#         "hostname": "state.smartproxy.com",
#         "port_range": "20501 - 20599"
#     },
#     {
#         "location": "South Dakota",
#         "hostname": "state.smartproxy.com",
#         "port_range": "20601 - 20699"
#     },
#     {
#         "location": "Tennessee",
#         "hostname": "state.smartproxy.com",
#         "port_range": "20701 - 20799"
#     },
#     {
#         "location": "Texas",
#         "hostname": "state.smartproxy.com",
#         "port_range": "14001 - 14999"
#     },
#     {
#         "location": "Utah",
#         "hostname": "state.smartproxy.com",
#         "port_range": "20801 - 20899"
#     },
#     {
#         "location": "Vermont",
#         "hostname": "state.smartproxy.com",
#         "port_range": "20901 - 20999"
#     },
#     {
#         "location": "Virginia",
#         "hostname": "state.smartproxy.com",
#         "port_range": "15001 - 15999"
#     },
#     {
#         "location": "Washington",
#         "hostname": "state.smartproxy.com",
#         "port_range": "16001 - 16999"
#     },
#     {
#         "location": "West Virginia",
#         "hostname": "state.smartproxy.com",
#         "port_range": "21001 - 21099"
#     },
#     {
#         "location": "Wisconsin",
#         "hostname": "state.smartproxy.com",
#         "port_range": "21101 - 21199"
#     },
#     {
#         "location": "Wyoming",
#         "hostname": "state.smartproxy.com",
#         "port_range": "21201 - 21299"
#     },
#     {
#         "location": "All",
#         "hostname": "all.dc.smartproxy.com",
#         "port_range": "10001 - 50000"
#     },
#     {
#         "location": "Europe",
#         "hostname": "eu.dc.smartproxy.com",
#         "port_range": "20001 - 31003"
#     },
#     {
#         "location": "Germany",
#         "hostname": "de.dc.smartproxy.com",
#         "port_range": "20001 - 25120"
#     },
#     {
#         "location": "Romania",
#         "hostname": "ro.dc.smartproxy.com",
#         "port_range": "20001 - 22556"
#     },
#     {
#         "location": "Netherlands",
#         "hostname": "nl.dc.smartproxy.com",
#         "port_range": "20001 - 20256"
#     },
#     {
#         "location": "United Kingdom",
#         "hostname": "uk.dc.smartproxy.com",
#         "port_range": "20001 - 22048"
#     }
# ]

# %%
country_list
# Out:
# [{'location': 'Random', 'prefix': 'gate'},
#  {'location': 'USA', 'prefix': 'us'},
#  {'location': 'Canada', 'prefix': 'ca'},
#  {'location': 'Great Britain', 'prefix': 'gb'},
#  {'location': 'Germany', 'prefix': 'de'},
#  {'location': 'France', 'prefix': 'fr'},
#  {'location': 'Spain', 'prefix': 'es'},
#  {'location': 'Italy', 'prefix': 'it'},
#  {'location': 'Sweden', 'prefix': 'se'},
#  {'location': 'Greece', 'prefix': 'gr'},
#  {'location': 'Portugal', 'prefix': 'pt'},
#  {'location': 'Netherlands', 'prefix': 'nl'},
#  {'location': 'Belgium', 'prefix': 'be'},
#  {'location': 'Russia', 'prefix': 'ru'},
#  {'location': 'Ukraine', 'prefix': 'ua'},
#  {'location': 'Poland', 'prefix': 'pl'},
#  {'location': 'Israel', 'prefix': 'il'},
#  {'location': 'Turkey', 'prefix': 'tr'},
#  {'location': 'Australia', 'prefix': 'au'},
#  {'location': 'Malaysia', 'prefix': 'my'},
#  {'location': 'Thailand', 'prefix': 'th'},
#  {'location': 'South Korea', 'prefix': 'kr'},
#  {'location': 'Japan', 'prefix': 'jp'},
#  {'location': 'Philippines', 'prefix': 'ph'},
#  {'location': 'Singapore', 'prefix': 'sg'},
#  {'location': 'China', 'prefix': 'cn'},
#  {'location': 'Hong Kong', 'prefix': 'hk'},
#  {'location': 'Taiwan', 'prefix': 'tw'},
#  {'location': 'India', 'prefix': 'in'},
#  {'location': 'Pakistan', 'prefix': 'pk'},
#  {'location': 'Iran', 'prefix': 'ir'},
#  {'location': 'Indonesia', 'prefix': 'id'},
#  {'location': 'Azerbaijan', 'prefix': 'az'},
#  {'location': 'Kazakhstan', 'prefix': 'kz'},
#  {'location': 'UAE', 'prefix': 'ae'},
#  {'location': 'Mexico', 'prefix': 'mx'},
#  {'location': 'Brazil', 'prefix': 'br'},
#  {'location': 'Argentina', 'prefix': 'ar'},
#  {'location': 'Chile', 'prefix': 'cl'},
#  {'location': 'Peru', 'prefix': 'pe'},
#  {'location': 'Ecuador', 'prefix': 'ec'},
#  {'location': 'Colombia', 'prefix': 'co'},
#  {'location': 'South Africa', 'prefix': 'za'},
#  {'location': 'Egypt', 'prefix': 'eg'},
#  {'location': 'Angola', 'prefix': 'ao'},
#  {'location': 'Cameroon', 'prefix': 'cm'},
#  {'location': 'Chad', 'prefix': 'td'},
#  {'location': 'Benin', 'prefix': 'bj'},
#  {'location': 'Ethiopia', 'prefix': 'et'},
#  {'location': 'Djibouti', 'prefix': 'dj'},
#  {'location': 'Gambia', 'prefix': 'gm'},
#  {'location': 'Ghana', 'prefix': 'gh'},
#  {'location': 'Kenya', 'prefix': 'ke'},
#  {'location': 'Liberia', 'prefix': 'lr'},
#  {'location': 'Madagascar', 'prefix': 'mg'},
#  {'location': 'Mali', 'prefix': 'ml'},
#  {'location': 'Mauritania', 'prefix': 'mr'},
#  {'location': 'Mauritius', 'prefix': 'mu'},
#  {'location': 'Morocco', 'prefix': 'ma'},
#  {'location': 'Mozambique', 'prefix': 'mz'},
#  {'location': 'Nigeria', 'prefix': 'ng'},
#  {'location': 'Senegal', 'prefix': 'sn'},
#  {'location': 'Seychelles', 'prefix': 'sc'},
#  {'location': 'Zimbabwe', 'prefix': 'zw'},
#  {'location': 'South Sudan', 'prefix': 'ss'},
#  {'location': 'Sudan', 'prefix': 'sd'},
#  {'location': 'Togo', 'prefix': 'tg'},
#  {'location': 'Tunisia', 'prefix': 'tn'},
#  {'location': 'Uganda', 'prefix': 'ug'},
#  {'location': 'Zambia', 'prefix': 'zm'},
#  {'location': 'Afghanistan', 'prefix': 'af'},
#  {'location': 'Bahrain', 'prefix': 'bh'},
#  {'location': 'Bangladesh', 'prefix': 'bd'},
#  {'location': 'Bhutan', 'prefix': 'bt'},
#  {'location': 'Myanmar', 'prefix': 'mm'},
#  {'location': 'Cambodia', 'prefix': 'kh'},
#  {'location': 'Iraq', 'prefix': 'iq'},
#  {'location': 'Jordan', 'prefix': 'jo'},
#  {'location': 'Lebanon', 'prefix': 'lb'},
#  {'location': 'Maldives', 'prefix': 'mv'},
#  {'location': 'Mongolia', 'prefix': 'mn'},
#  {'location': 'Oman', 'prefix': 'om'},
#  {'location': 'Qatar', 'prefix': 'qa'},
#  {'location': 'Saudi Arabia', 'prefix': 'sa'},
#  {'location': 'Turkmenistan', 'prefix': 'tm'},
#  {'location': 'Uzbekistan', 'prefix': 'uz'},
#  {'location': 'Yemen', 'prefix': 'ye'},
#  {'location': 'Albania', 'prefix': 'al'},
#  {'location': 'Andorra', 'prefix': 'ad'},
#  {'location': 'Austria', 'prefix': 'at'},
#  {'location': 'Armenia', 'prefix': 'am'},
#  {'location': 'Bosnia and Herzegovina', 'prefix': 'ba'},
#  {'location': 'Bulgaria', 'prefix': 'bg'},
#  {'location': 'Belarus', 'prefix': 'by'},
#  {'location': 'Croatia', 'prefix': 'hr'},
#  {'location': 'Cyprus', 'prefix': 'cy'},
#  {'location': 'Czech Republic', 'prefix': 'cz'},
#  {'location': 'Denmark', 'prefix': 'dk'},
#  {'location': 'Estonia', 'prefix': 'ee'},
#  {'location': 'Finland', 'prefix': 'fi'},
#  {'location': 'Georgia', 'prefix': 'ge'},
#  {'location': 'Hungary', 'prefix': 'hu'},
#  {'location': 'Iceland', 'prefix': 'is'},
#  {'location': 'Ireland', 'prefix': 'ie'},
#  {'location': 'Latvia', 'prefix': 'lv'},
#  {'location': 'Liechtenstein', 'prefix': 'li'},
#  {'location': 'Lithuania', 'prefix': 'lt'},
#  {'location': 'Luxembourg', 'prefix': 'lu'},
#  {'location': 'Monaco', 'prefix': 'mc'},
#  {'location': 'Moldova', 'prefix': 'md'},
#  {'location': 'Montenegro', 'prefix': 'me'},
#  {'location': 'Norway', 'prefix': 'no'},
#  {'location': 'Romania', 'prefix': 'ro'},
#  {'location': 'Serbia', 'prefix': 'rs'},
#  {'location': 'Slovakia', 'prefix': 'sk'},
#  {'location': 'Slovenia', 'prefix': 'si'},
#  {'location': 'Switzerland', 'prefix': 'ch'},
#  {'location': 'Macedonia', 'prefix': 'mk'},
#  {'location': 'Bahamas', 'prefix': 'bs'},
#  {'location': 'Belize', 'prefix': 'bz'},
#  {'location': 'British Virgin Islands', 'prefix': 'vg'},
#  {'location': 'Costa Rica', 'prefix': 'cr'},
#  {'location': 'Cuba', 'prefix': 'cu'},
#  {'location': 'Dominica', 'prefix': 'dm'},
#  {'location': 'Haiti', 'prefix': 'ht'},
#  {'location': 'Honduras', 'prefix': 'hn'},
#  {'location': 'Jamaica', 'prefix': 'jm'},
#  {'location': 'Aruba', 'prefix': 'aw'},
#  {'location': 'Panama', 'prefix': 'pa'},
#  {'location': 'Puerto Rico', 'prefix': 'pr'},
#  {'location': 'Trinidad and Tobago', 'prefix': 'tt'},
#  {'location': 'Fiji', 'prefix': 'fj'},
#  {'location': 'New Zealand', 'prefix': 'nz'},
#  {'location': 'Bolivia', 'prefix': 'bo'},
#  {'location': 'Paraguay', 'prefix': 'py'},
#  {'location': 'Uruguay', 'prefix': 'uy'},
#  {'location': "Côte d'Ivoire", 'prefix': 'ci'},
#  {'location': 'Syria', 'prefix': 'sy'},
#  {'location': 'New York', 'prefix': 'city'},
#  {'location': 'Los Angeles', 'prefix': 'city'},
#  {'location': 'Chicago', 'prefix': 'city'},
#  {'location': 'Houston', 'prefix': 'city'},
#  {'location': 'Miami', 'prefix': 'city'},
#  {'location': 'London', 'prefix': 'city'},
#  {'location': 'Berlin', 'prefix': 'city'},
#  {'location': 'Moscow', 'prefix': 'city'},
#  {'location': 'Vietnam', 'prefix': 'vn'},
#  {'location': 'US', 'prefix': 'gate'},
#  {'location': 'Malta', 'prefix': 'mt'},
#  {'location': 'Europe', 'prefix': 'eu'},
#  {'location': 'Alabama', 'prefix': 'state'},
#  {'location': 'Alaska', 'prefix': 'state'},
#  {'location': 'Arizona', 'prefix': 'state'},
#  {'location': 'Arkansas', 'prefix': 'state'},
#  {'location': 'California', 'prefix': 'state'},
#  {'location': 'Colorado', 'prefix': 'state'},
#  {'location': 'Connecticut', 'prefix': 'state'},
#  {'location': 'Delaware', 'prefix': 'state'},
#  {'location': 'Florida', 'prefix': 'state'},
#  {'location': 'Georgia (US)', 'prefix': 'state'},
#  {'location': 'Hawaii', 'prefix': 'state'},
#  {'location': 'Idaho', 'prefix': 'state'},
#  {'location': 'Illinois', 'prefix': 'state'},
#  {'location': 'Indiana', 'prefix': 'state'},
#  {'location': 'Iowa', 'prefix': 'state'},
#  {'location': 'Kansas', 'prefix': 'state'},
#  {'location': 'Kentucky', 'prefix': 'state'},
#  {'location': 'Louisiana', 'prefix': 'state'},
#  {'location': 'Maine', 'prefix': 'state'},
#  {'location': 'Maryland', 'prefix': 'state'},
#  {'location': 'Massachusetts', 'prefix': 'state'},
#  {'location': 'Michigan', 'prefix': 'state'},
#  {'location': 'Minnesota', 'prefix': 'state'},
#  {'location': 'Mississippi', 'prefix': 'state'},
#  {'location': 'Missouri', 'prefix': 'state'},
#  {'location': 'Montana', 'prefix': 'state'},
#  {'location': 'Nebraska', 'prefix': 'state'},
#  {'location': 'Nevada', 'prefix': 'state'},
#  {'location': 'New Hampshire', 'prefix': 'state'},
#  {'location': 'New Jersey', 'prefix': 'state'},
#  {'location': 'New Mexico', 'prefix': 'state'},
#  {'location': 'New York', 'prefix': 'state'},
#  {'location': 'North Carolina', 'prefix': 'state'},
#  {'location': 'North Dakota', 'prefix': 'state'},
#  {'location': 'Ohio', 'prefix': 'state'},
#  {'location': 'Oklahoma', 'prefix': 'state'},
#  {'location': 'Oregon', 'prefix': 'state'},
#  {'location': 'Pennsylvania', 'prefix': 'state'},
#  {'location': 'Rhode Island', 'prefix': 'state'},
#  {'location': 'South Carolina', 'prefix': 'state'},
#  {'location': 'South Dakota', 'prefix': 'state'},
#  {'location': 'Tennessee', 'prefix': 'state'},
#  {'location': 'Texas', 'prefix': 'state'},
#  {'location': 'Utah', 'prefix': 'state'},
#  {'location': 'Vermont', 'prefix': 'state'},
#  {'location': 'Virginia', 'prefix': 'state'},
#  {'location': 'Washington', 'prefix': 'state'},
#  {'location': 'West Virginia', 'prefix': 'state'},
#  {'location': 'Wisconsin', 'prefix': 'state'},
#  {'location': 'Wyoming', 'prefix': 'state'},
#  {'location': 'All', 'prefix': 'all'},
#  {'location': 'Europe', 'prefix': 'eu'},
#  {'location': 'Germany', 'prefix': 'de'},
#  {'location': 'Romania', 'prefix': 'ro'},
#  {'location': 'Netherlands', 'prefix': 'nl'},
#  {'location': 'United Kingdom', 'prefix': 'uk'}]

# %%
import requests

# Define the URL for retrieving IP info
url = 'https://ip.smartproxy.com/json'

# Proxy generation function
def retrieve_proxy(sticky_time, country, session_id):
    """
    Generates the Smartproxy username dynamically based on session parameters.
    """
    username = f'user-spaydccim2-session-{session_id}-sessionduration-{sticky_time}-country-{country}'
    return username

# Parameters for the proxy session
sticky_time = 60
country = 'tr'  # Change country as needed, 'gr' for Greece, 'us' for USA, etc.
session_id = '10'  # This indicates the proxy session

# Call the function to generate the username
username = retrieve_proxy(sticky_time, country, session_id)

# Define the password and proxy URL
password = 'o2EF7qdxd4~ncFre6U'  # Your Smartproxy password
proxy = f"socks5h://{username}:{password}@gate.smartproxy.com:7000"

# Make the request using the generated proxy
result = requests.get(url, proxies={
    'http': proxy,
    'https': proxy
})

# Print the result to verify if the proxy is working correctly
formatted_response = json.loads(result.text)
print(json.dumps(formatted_response, indent=4))
# Out:
# {
#     "browser": {
#         "name": "",
#         "version": ""
#     },
#     "platform": {
#         "os": "undefined undefined"
#     },
#     "engine": {},
#     "isp": {
#         "isp": "Vodafone Net Iletisim Hizmetler",
#         "asn": 15924,
#         "domain": "",
#         "organization": "Vodafone Net Iletisim Hizmetler"
#     },
#     "city": {
#         "name": "Istanbul",
#         "code": "34",
#         "state": "Istanbul",
#         "time_zone": "Europe/Istanbul",
#         "zip_code": "34096",
#         "latitude": 41.0145,
#         "longitude": 28.9533
#     },
#     "proxy": {
#         "ip": "212.12.142.175"
#     },
#     "country": {
#         "code": "TR",
#         "name": "T\u00fcrkiye",
#         "continent": "Asia"
#     }
# }
