# %%
import requests
import json

# Function to construct the proxy URL dynamically based on session parameters
def construct_proxy_url(username, password, session_id, sticky_time, country):
    """
    Constructs the Smartproxy URL dynamically based on session parameters.
    """
    # Construct the proxy link based on the session
    # proxy_url = f"socks5://{username}-session-{session_id}-sessionduration-{sticky_time}-country-{country}:{password}@gate.smartproxy.com:7000"
    proxy_url = f"socks5://{username}-session-{session_id}-sessionduration-{sticky_time}-country-{country}:{password}@gate.visitxiangtan.com:7000"
    return proxy_url

# Function to generate multiple proxies and retrieve their associated IPs
def get_proxies_and_ips(username, password, sticky_time, country, num_sessions):
    """
    Generates multiple proxy sessions and retrieves IP addresses for each session.
    
    Args:
    - username: The Smartproxy username.
    - password: The Smartproxy password.
    - sticky_time: The session duration in seconds.
    - country: The country code for the proxy.
    - num_sessions: The number of proxy sessions to generate.
    
    Returns:
    - A list of IP addresses retrieved from the proxy sessions.
    """
    proxy_ips = []
    url = 'https://ip.smartproxy.com/json'
    
    for session_id in range(20, 20 + num_sessions + 1):
        proxy_url = construct_proxy_url(username, password, session_id, sticky_time, country)
        try:
            # Make the request using the generated proxy
            result = requests.get(url, proxies={
                'http': proxy_url,
                'https': proxy_url
            })
            if result.status_code == 200:
                formatted_response = json.loads(result.text)
                ip = formatted_response.get('proxy', {}).get('ip', 'IP not found')
                country_code = formatted_response.get('country', {}).get('name', 'Country code not found')
                proxy_ips.append(ip)
                # Print IP first, followed by the respective proxy link
                print(f"Session {session_id} - IP: {ip}, Proxy: {proxy_url}")
                print(f"Country: {country_code}")
            else:
                print(f"Failed to retrieve IP for session {session_id}. Status code: {result.status_code}")
        
        except Exception as e:
            print(f"Error in session {session_id}: {str(e)}")
    
    return proxy_ips

# Example usage
username = 'user-sp797yej9h'  # Your Smartproxy username
password = 'n7x6Tsj73Kpz_DmRkt'  # Your Smartproxy password
sticky_time = 30  # Set the sticky time (in minutes)
country = 'uk'  # Set the country code (e.g., 'cn' for China)
num_sessions = 20  # Number of proxy sessions

# Retrieve proxies and IPs for the specified number of sessions
proxy_ips = get_proxies_and_ips(username, password, sticky_time, country, num_sessions)
print("Retrieved IPs:", proxy_ips)
# Out:
# Error in session 20: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fdfccf90>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 21: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fe104950>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 22: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fe011190>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 23: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fdfc4710>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 24: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fe106310>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 25: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fe176310>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 26: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fe110350>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 27: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fe177210>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 28: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7ff2d1750>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 29: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fdfc68d0>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 30: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fe18ff90>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 31: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fe1126d0>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 32: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fdfc77d0>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 33: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fe18d690>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 34: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fe0101d0>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 35: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fe174650>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 36: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fe110d50>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 37: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7ff2e3d10>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 38: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fdfce050>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 39: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fdfcc0d0>: Failed to establish a new connection: Connection closed unexpectedly'))
# Error in session 40: SOCKSHTTPSConnectionPool(host='ip.smartproxy.com', port=443): Max retries exceeded with url: /json (Caused by NewConnectionError('<urllib3.contrib.socks.SOCKSHTTPSConnection object at 0x7fa7fe3e1790>: Failed to establish a new connection: Connection closed unexpectedly'))
# Retrieved IPs: []

# %%
import requests
import json

# Function to construct the proxy URL dynamically based on session parameters
def construct_proxy_url_for_state(username, password, session_id, sticky_time, state):
    """
    Constructs the Smartproxy URL dynamically based on session parameters for U.S. states.
    """
    # Construct the proxy link based on the session
    proxy_url = f"socks5://{username}-session-{session_id}-sessionduration-{sticky_time}-state-{state}:{password}@gate.visitxiangtan.com:7000"
    return proxy_url

# Function to generate multiple proxies and retrieve their associated IPs
def get_proxies_and_ips_for_states(username, password, sticky_time, state, num_sessions):
    """
    Generates multiple proxy sessions for specific U.S. states and retrieves IP addresses for each session.
    
    Args:
    - username: The Smartproxy username.
    - password: The Smartproxy password.
    - sticky_time: The session duration in seconds.
    - state: The state code for the proxy (e.g., "us_california").
    - num_sessions: The number of proxy sessions to generate.
    
    Returns:
    - A list of IP addresses retrieved from the proxy sessions.
    """
    proxy_ips = []
    url = 'https://ip.smartproxy.com/json'
    
    for session_id in range(20, 20 + num_sessions + 1):
        proxy_url = construct_proxy_url_for_state(username, password, session_id, sticky_time, state)
        try:
            # Make the request using the generated proxy
            result = requests.get(url, proxies={
                'http': proxy_url,
                'https': proxy_url
            })
            if result.status_code == 200:
                formatted_response = json.loads(result.text)
                ip = formatted_response.get('proxy', {}).get('ip', 'IP not found')
                country_code = formatted_response.get('country', {}).get('name', 'Country code not found')
                proxy_ips.append(ip)
                # Print IP first, followed by the respective proxy link
                print(f"Session {session_id} - IP: {ip}, Proxy: {proxy_url}")
                print(f"Country/State: {country_code}")
            else:
                print(f"Failed to retrieve IP for session {session_id}. Status code: {result.status_code}")
        
        except Exception as e:
            print(f"Error in session {session_id}: {str(e)}")
    
    return proxy_ips

# Example usage
username = 'user-sp797yej9h'  # Your Smartproxy username
password = 'n7x6Tsj73Kpz_DmRkt'  # Your Smartproxy password
sticky_time = 30  # Set the sticky time (in minutes)
state = 'us_california'  # Set the U.S. state code (e.g., 'us_california' for California)
num_sessions = 20  # Number of proxy sessions

# Retrieve proxies and IPs for the specified number of sessions
proxy_ips = get_proxies_and_ips_for_states(username, password, sticky_time, state, num_sessions)
print("Retrieved IPs:", proxy_ips)
