# %%
import requests
import json

# Function to construct the proxy URL dynamically based on session parameters
def construct_proxy_url(username, password, session_id, sticky_time, country):
    """
    Constructs the Smartproxy URL dynamically based on session parameters.
    """
    # Construct the proxy link based on the session
    # proxy_url = f"socks5://{username}-session-{session_id}-sessionduration-{sticky_time}-country-{country}:{password}@gate.smartproxy.com:7000"
    proxy_url = f"socks5://{username}-session-{session_id}-sessionduration-{sticky_time}-country-{country}:{password}@gate.visitxiangtan.com:7000"
    return proxy_url

# Function to generate multiple proxies and retrieve their associated IPs
def get_proxies_and_ips(username, password, sticky_time, country, num_sessions):
    """
    Generates multiple proxy sessions and retrieves IP addresses for each session.
    
    Args:
    - username: The Smartproxy username.
    - password: The Smartproxy password.
    - sticky_time: The session duration in seconds.
    - country: The country code for the proxy.
    - num_sessions: The number of proxy sessions to generate.
    
    Returns:
    - A list of IP addresses retrieved from the proxy sessions.
    """
    proxy_ips = []
    url = 'https://ip.smartproxy.com/json'
    
    for session_id in range(20, 20 + num_sessions + 1):
        proxy_url = construct_proxy_url(username, password, session_id, sticky_time, country)
        try:
            # Make the request using the generated proxy
            result = requests.get(url, proxies={
                'http': proxy_url,
                'https': proxy_url
            })
            if result.status_code == 200:
                formatted_response = json.loads(result.text)
                ip = formatted_response.get('proxy', {}).get('ip', 'IP not found')
                country_code = formatted_response.get('country', {}).get('name', 'Country code not found')
                proxy_ips.append(ip)
                # Print IP first, followed by the respective proxy link
                print(f"Session {session_id} - IP: {ip}, Proxy: {proxy_url}")
                print(f"Country: {country_code}")
            else:
                print(f"Failed to retrieve IP for session {session_id}. Status code: {result.status_code}")
        
        except Exception as e:
            print(f"Error in session {session_id}: {str(e)}")
    
    return proxy_ips

# Example usage
username = 'user-sp797yej9h'  # Your Smartproxy username
password = 'n7x6Tsj73Kpz_DmRkt'  # Your Smartproxy password
sticky_time = 30  # Set the sticky time (in minutes)
country = 'de'  # Set the country code (e.g., 'cn' for China)
num_sessions = 20  # Number of proxy sessions

# Retrieve proxies and IPs for the specified number of sessions
proxy_ips = get_proxies_and_ips(username, password, sticky_time, country, num_sessions)
print("Retrieved IPs:", proxy_ips)
# Out:
# Session 20 - IP: 46.223.162.150, Proxy: socks5://user-sp797yej9h-session-20-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 21 - IP: 87.189.185.217, Proxy: socks5://user-sp797yej9h-session-21-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 22 - IP: 95.222.30.26, Proxy: socks5://user-sp797yej9h-session-22-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 23 - IP: 176.6.50.6, Proxy: socks5://user-sp797yej9h-session-23-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 24 - IP: 95.116.19.1, Proxy: socks5://user-sp797yej9h-session-24-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 25 - IP: 92.72.47.4, Proxy: socks5://user-sp797yej9h-session-25-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 26 - IP: 176.199.209.208, Proxy: socks5://user-sp797yej9h-session-26-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 27 - IP: 79.209.4.52, Proxy: socks5://user-sp797yej9h-session-27-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 28 - IP: 2.243.78.11, Proxy: socks5://user-sp797yej9h-session-28-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 29 - IP: 84.136.125.171, Proxy: socks5://user-sp797yej9h-session-29-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 30 - IP: 89.244.95.86, Proxy: socks5://user-sp797yej9h-session-30-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 31 - IP: 217.245.121.191, Proxy: socks5://user-sp797yej9h-session-31-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 32 - IP: 84.139.248.20, Proxy: socks5://user-sp797yej9h-session-32-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 33 - IP: 93.228.110.13, Proxy: socks5://user-sp797yej9h-session-33-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 34 - IP: 77.0.16.185, Proxy: socks5://user-sp797yej9h-session-34-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 35 - IP: 37.201.213.190, Proxy: socks5://user-sp797yej9h-session-35-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 36 - IP: 92.200.147.120, Proxy: socks5://user-sp797yej9h-session-36-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 37 - IP: 77.64.255.32, Proxy: socks5://user-sp797yej9h-session-37-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 38 - IP: 95.222.26.206, Proxy: socks5://user-sp797yej9h-session-38-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 39 - IP: 91.42.248.175, Proxy: socks5://user-sp797yej9h-session-39-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Session 40 - IP: 92.217.189.79, Proxy: socks5://user-sp797yej9h-session-40-sessionduration-30-country-de:n7x6Tsj73Kpz_DmRkt@gate.visitxiangtan.com:7000
# Country: Germany
# Retrieved IPs: ['46.223.162.150', '87.189.185.217', '95.222.30.26', '176.6.50.6', '95.116.19.1', '92.72.47.4', '176.199.209.208', '79.209.4.52', '2.243.78.11', '84.136.125.171', '89.244.95.86', '217.245.121.191', '84.139.248.20', '93.228.110.13', '77.0.16.185', '37.201.213.190', '92.200.147.120', '77.64.255.32', '95.222.26.206', '91.42.248.175', '92.217.189.79']

# %%
import requests
import json

# Function to construct the proxy URL dynamically based on session parameters
def construct_proxy_url_for_state(username, password, session_id, sticky_time, state):
    """
    Constructs the Smartproxy URL dynamically based on session parameters for U.S. states.
    """
    # Construct the proxy link based on the session
    proxy_url = f"socks5://{username}-session-{session_id}-sessionduration-{sticky_time}-state-{state}:{password}@gate.visitxiangtan.com:7000"
    return proxy_url

# Function to generate multiple proxies and retrieve their associated IPs
def get_proxies_and_ips_for_states(username, password, sticky_time, state, num_sessions):
    """
    Generates multiple proxy sessions for specific U.S. states and retrieves IP addresses for each session.
    
    Args:
    - username: The Smartproxy username.
    - password: The Smartproxy password.
    - sticky_time: The session duration in seconds.
    - state: The state code for the proxy (e.g., "us_california").
    - num_sessions: The number of proxy sessions to generate.
    
    Returns:
    - A list of IP addresses retrieved from the proxy sessions.
    """
    proxy_ips = []
    url = 'https://ip.smartproxy.com/json'
    
    for session_id in range(20, 20 + num_sessions + 1):
        proxy_url = construct_proxy_url_for_state(username, password, session_id, sticky_time, state)
        try:
            # Make the request using the generated proxy
            result = requests.get(url, proxies={
                'http': proxy_url,
                'https': proxy_url
            })
            if result.status_code == 200:
                formatted_response = json.loads(result.text)
                ip = formatted_response.get('proxy', {}).get('ip', 'IP not found')
                country_code = formatted_response.get('country', {}).get('name', 'Country code not found')
                proxy_ips.append(ip)
                # Print IP first, followed by the respective proxy link
                print(f"Session {session_id} - IP: {ip}, Proxy: {proxy_url}")
                print(f"Country/State: {country_code}")
            else:
                print(f"Failed to retrieve IP for session {session_id}. Status code: {result.status_code}")
        
        except Exception as e:
            print(f"Error in session {session_id}: {str(e)}")
    
    return proxy_ips

# Example usage
username = 'user-sp797yej9h'  # Your Smartproxy username
password = 'n7x6Tsj73Kpz_DmRkt'  # Your Smartproxy password
sticky_time = 30  # Set the sticky time (in minutes)
state = 'us_california'  # Set the U.S. state code (e.g., 'us_california' for California)
num_sessions = 20  # Number of proxy sessions

# Retrieve proxies and IPs for the specified number of sessions
proxy_ips = get_proxies_and_ips_for_states(username, password, sticky_time, state, num_sessions)
print("Retrieved IPs:", proxy_ips)
