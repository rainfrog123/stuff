# %%
import requests

# List of proxies from the table
proxies = [
    {"ip": "38.154.227.167", "port": "5868", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "45.127.248.127", "port": "5128", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "207.244.217.165", "port": "6712", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "HR"},
    {"ip": "64.64.118.149", "port": "6732", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "167.160.180.203", "port": "6754", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "104.239.105.125", "port": "6655", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "198.105.101.92", "port": "5721", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "GB"},
    {"ip": "154.36.110.199", "port": "6853", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "DE"},
    {"ip": "204.44.69.89", "port": "6342", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "206.41.172.74", "port": "6634", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "FR"},
]

# URL to test
test_url = "https://httpbin.org/ip"  # This service returns the IP address used to make the request.

def check_proxy(proxy):
    try:
        # Setup the proxy format for requests
        proxy_url = f"http://{proxy['username']}:{proxy['password']}@{proxy['ip']}:{proxy['port']}"
        proxies_dict = {
            "http": proxy_url,
            "https": proxy_url,
        }

        # Make a request through the proxy
        response = requests.get(test_url, proxies=proxies_dict, timeout=10)

        # If the request is successful, print the response IP (from the proxy)
        if response.status_code == 200:
            print(f"Proxy {proxy['ip']}:{proxy['port']} ({proxy['country']}) is working. Response IP: {response.json()['origin']}")
        else:
            print(f"Proxy {proxy['ip']}:{proxy['port']} ({proxy['country']}) is not working. Status code: {response.status_code}")

    except requests.exceptions.RequestException as e:
        print(f"Proxy {proxy['ip']}:{proxy['port']} ({proxy['country']}) failed. Error: {str(e)}")


# Iterate over each proxy and check if it's working
for proxy in proxies:
    check_proxy(proxy)

# %%
import requests

# List of proxies from the table
proxies = [
    {"ip": "38.154.227.167", "port": "5868", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "45.127.248.127", "port": "5128", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "207.244.217.165", "port": "6712", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "HR"},
    {"ip": "64.64.118.149", "port": "6732", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "167.160.180.203", "port": "6754", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "104.239.105.125", "port": "6655", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "198.105.101.92", "port": "5721", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "GB"},
    {"ip": "154.36.110.199", "port": "6853", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "DE"},
    {"ip": "204.44.69.89", "port": "6342", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "206.41.172.74", "port": "6634", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "FR"},
]

# The URL to visit
url = "http://www.play86.net/u.asp?id=950539"
# url = "http://www.google.com"

def visit_with_proxy(proxy):
    try:
        # Setup the proxy format for requests
        proxy_url = f"http://{proxy['username']}:{proxy['password']}@{proxy['ip']}:{proxy['port']}"
        proxies_dict = {
            "http": proxy_url,
            "https": proxy_url,
        }

        # Make a request to the given URL through the proxy
        response = requests.get(url, proxies=proxies_dict, timeout=10)

        # Check if the request was successful
        if response.status_code == 200:
            print(f"Proxy {proxy['ip']}:{proxy['port']} ({proxy['country']}) successfully visited the URL.")
        else:
            print(f"Proxy {proxy['ip']}:{proxy['port']} ({proxy['country']}) failed to visit the URL. Status code: {response.status_code}")

    except requests.exceptions.RequestException as e:
        print(f"Proxy {proxy['ip']}:{proxy['port']} ({proxy['country']}) encountered an error: {str(e)}")


# Iterate over each proxy and attempt to visit the URL
for proxy in proxies:
    visit_with_proxy(proxy)

# %%
import undetected_chromedriver as uc
from selenium.webdriver.common.proxy import Proxy, ProxyType

# List of proxies from the table
proxies = [
    {"ip": "38.154.227.167", "port": "5868", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "45.127.248.127", "port": "5128", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "207.244.217.165", "port": "6712", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "HR"},
    {"ip": "64.64.118.149", "port": "6732", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "167.160.180.203", "port": "6754", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "104.239.105.125", "port": "6655", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "198.105.101.92", "port": "5721", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "GB"},
    {"ip": "154.36.110.199", "port": "6853", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "DE"},
    {"ip": "204.44.69.89", "port": "6342", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "US"},
    {"ip": "206.41.172.74", "port": "6634", "username": "vmfblpzs", "password": "u70jq9op8ef6", "country": "FR"},
]

# The URL to visit
url = "http://www.play86.net/u.asp?id=950539"

def setup_proxy(proxy):
    """
    Configures ChromeDriver with a proxy.
    """
    options = uc.ChromeOptions()
    proxy_address = f"{proxy['ip']}:{proxy['port']}"
    
    # Add proxy configuration
    proxy_options = {
        "proxyType": ProxyType.MANUAL,
        "httpProxy": proxy_address,
        "sslProxy": proxy_address,
        "ftpProxy": proxy_address,
        "noProxy": ""
    }

    proxy = Proxy(proxy_options)
    capabilities = uc.webdriver.DesiredCapabilities.CHROME.copy()
    proxy.add_to_capabilities(capabilities)

    # Set up username and password for proxy (via Chrome's built-in support for proxy auth extensions)
    chrome_prefs = {
        'profile.default_content_setting_values': {
            'notifications': 2
        },
        'credentials_enable_service': False,
        'profile.password_manager_enabled': False
    }
    
    options.add_argument(f'--proxy-server=http://{proxy["ip"]}:{proxy["port"]}')
    options.add_experimental_option("prefs", chrome_prefs)
    driver = uc.Chrome(options=options, desired_capabilities=capabilities)
    
    return driver

def visit_with_proxy(proxy):
    """
    Visits the given URL through the specified proxy using undetected-chromedriver.
    """
    try:
        driver = setup_proxy(proxy)
        driver.get(url)

        # Print success message if the page loads correctly
        print(f"Successfully visited the URL with proxy {proxy['ip']}:{proxy['port']} ({proxy['country']}).")

    except Exception as e:
        print(f"Failed to visit the URL with proxy {proxy['ip']}:{proxy['port']} ({proxy['country']}). Error: {str(e)}")
    
    finally:
        # Always close the driver at the end of each attempt
        driver.quit()

# Iterate over each proxy and attempt to visit the URL
for proxy in proxies:
    visit_with_proxy(proxy)
