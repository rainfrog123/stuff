# %%
import requests

proxies = [
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-1a31050d@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-485aab63@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-244ea0f4@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-faf25472@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-ee1d278f@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-c3c29223@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-55d7c419@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-ce68f56b@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-5cada658@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-49b328c1@la.residential.rayobyte.com:8000"
]

def test_proxy(proxy_url):
    proxy = {
        "http": f"http://{proxy_url}",
        "https": f"http://{proxy_url}",
    }
    try:
        response = requests.get("http://ipinfo.io/json", proxies=proxy, timeout=10)
        print(f"Proxy {proxy_url} is working. Response: {response.json()}")
    except Exception as e:
        print(f"Proxy {proxy_url} failed. Error: {e}")

for proxy in proxies:
    test_proxy(proxy)

# %%
import requests

# List of proxies
proxies = [
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-1a31050d@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-485aab63@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-244ea0f4@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-faf25472@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-ee1d278f@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-c3c29223@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-55d7c419@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-ce68f56b@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-5cada658@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-49b328c1@la.residential.rayobyte.com:8000"
]

# IPQualityScore API key
api_key = "FpWURHkY8cHf2p4vOiW43ldS5lKe5BNc"

def get_fraud_score(ip):
    url = f"https://ipqualityscore.com/api/json/ip/{api_key}/{ip}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return data.get("fraud_score")
    return None

def test_proxy(proxy_url):
    proxy = {
        "http": f"http://{proxy_url}",
        "https": f"http://{proxy_url}",
    }
    try:
        # Get the public IP using the proxy
        response = requests.get("http://ipinfo.io/ip", proxies=proxy, timeout=10)
        if response.status_code == 200:
            ip = response.text.strip()
            fraud_score = get_fraud_score(ip)
            print(f"Proxy IP: {ip}, Fraud Score: {fraud_score}")
        else:
            print(f"Failed to fetch IP info using proxy {proxy_url}")
    
    except Exception as e:
        print(f"Proxy {proxy_url} failed. Error: {e}")

# Check each proxy
for proxy in proxies:
    test_proxy(proxy)

# %%
import requests

# Function to format proxy list from raw text
def format_proxy_list(proxy_string):
    proxy_lines = proxy_string.strip().split("\n")
    formatted_proxies = [line.strip() for line in proxy_lines]  # Removed extra double quotes
    return formatted_proxies

# Raw proxy list text (replace this with actual text from the website or file)
proxy_string = """
denmark_edgesoftware_xyz:nimasile-country-SE@la.residential.rayobyte.com:8000
denmark_edgesoftware_xyz:nimasile-country-SE@la.residential.rayobyte.com:8000
denmark_edgesoftware_xyz:nimasile-country-SE@la.residential.rayobyte.com:8000
denmark_edgesoftware_xyz:nimasile-country-SE@la.residential.rayobyte.com:8000
denmark_edgesoftware_xyz:nimasile-country-SE@la.residential.rayobyte.com:8000
denmark_edgesoftware_xyz:nimasile-country-SE@la.residential.rayobyte.com:8000
denmark_edgesoftware_xyz:nimasile-country-SE@la.residential.rayobyte.com:8000
denmark_edgesoftware_xyz:nimasile-country-SE@la.residential.rayobyte.com:8000
denmark_edgesoftware_xyz:nimasile-country-SE@la.residential.rayobyte.com:8000
denmark_edgesoftware_xyz:nimasile-country-SE@la.residential.rayobyte.com:8000
"""

# Format and set proxy list
proxies = format_proxy_list(proxy_string)

# IPQualityScore API key
api_key = "FpWURHKy8cHf2p4vOiW43ldS5IKe5BNc"

# Function to get the fraud score from IPQualityScore API
def get_fraud_score(ip):
    url = f"https://ipqualityscore.com/api/json/ip/{api_key}/{ip}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return data.get("fraud_score")
    else:
        print(f"Failed to retrieve fraud score for IP: {ip}")
        return None

# Function to test proxy and get the public IP using it
def test_proxy(proxy_url):
    proxy = {
        "http": f"http://{proxy_url}",
        "https": f"http://{proxy_url}",
    }
    try:
        # Get the public IP using the proxy
        response = requests.get("http://ipinfo.io/ip", proxies=proxy, timeout=10)
        if response.status_code == 200:
            ip = response.text.strip()
            fraud_score = get_fraud_score(ip)
            if fraud_score == 0:
                print(f"Proxy IP: {ip}, Fraud Score: {fraud_score} (Using Proxy: {proxy_url})")
            else:
                print(f"Proxy IP: {ip}, Fraud Score: {fraud_score}")
        else:
            print(f"Failed to fetch IP info using proxy {proxy_url}")
    except Exception as e:
        print(f"Proxy {proxy_url} failed. Error: {e}")

# Check each proxy
for proxy in proxies:
    test_proxy(proxy)
# Out:
# Proxy IP: 90.226.131.234, Fraud Score: 20
# Proxy IP: 212.85.92.68, Fraud Score: 100
# Proxy IP: 78.67.56.188, Fraud Score: 30
# Proxy IP: 80.216.9.132, Fraud Score: 20
# Proxy IP: 81.92.27.129, Fraud Score: 100

# %%
import requests

# List of proxies
proxies = [
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-1a31050d@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-485aab63@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-244ea0f4@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-faf25472@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-ee1d278f@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-c3c29223@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-55d7c419@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-ce68f56b@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-5cada658@la.residential.rayobyte.com:8000",
    "denmark_edgesoftware_xyz:nimasile-country-DK-session-49b328c1@la.residential.rayobyte.com:8000"
]

# IPQualityScore API key
api_key = "FpWURHKy8cHf2p4vOiW43ldS5IKe5BNc"

# Function to get the fraud score from IPQualityScore API
def get_fraud_score(ip):
    url = f"https://ipqualityscore.com/api/json/ip/{api_key}/{ip}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return data.get("fraud_score")
    else:
        print(f"Failed to retrieve fraud score for IP: {ip}")
        return None

# Function to test proxy and get the public IP using it
def test_proxy(proxy_url):
    proxy = {
        "http": f"http://{proxy_url}",
        "https": f"http://{proxy_url}",
    }
    try:
        # Get the public IP using the proxy
        response = requests.get("http://ipinfo.io/ip", proxies=proxy, timeout=10)
        if response.status_code == 200:
            ip = response.text.strip()
            fraud_score = get_fraud_score(ip)
            if fraud_score == 0:
                print(f"Proxy IP: {ip}, Fraud Score: {fraud_score} (Using Proxy: {proxy_url})")
            else:
                print(f"Proxy IP: {ip}, Fraud Score: {fraud_score}")
        else:
            print(f"Failed to fetch IP info using proxy {proxy_url}")
    except Exception as e:
        print(f"Proxy {proxy_url} failed. Error: {e}")

# Check each proxy
for proxy in proxies:
    test_proxy(proxy)
# Out:
# Proxy IP: 89.23.224.136, Fraud Score: 30
# Failed to fetch IP info using proxy denmark_edgesoftware_xyz:nimasile-country-DK-session-485aab63@la.residential.rayobyte.com:8000
# Proxy IP: 85.203.220.156, Fraud Score: 20
# Proxy IP: 91.100.146.52, Fraud Score: 0 (Using Proxy: denmark_edgesoftware_xyz:nimasile-country-DK-session-faf25472@la.residential.rayobyte.com:8000)
# Proxy IP: 85.24.95.133, Fraud Score: 30
# Proxy IP: 37.96.113.82, Fraud Score: 0 (Using Proxy: denmark_edgesoftware_xyz:nimasile-country-DK-session-c3c29223@la.residential.rayobyte.com:8000)
# Proxy IP: 80.210.69.58, Fraud Score: 0 (Using Proxy: denmark_edgesoftware_xyz:nimasile-country-DK-session-55d7c419@la.residential.rayobyte.com:8000)
# Proxy IP: 85.203.211.231, Fraud Score: 0 (Using Proxy: denmark_edgesoftware_xyz:nimasile-country-DK-session-ce68f56b@la.residential.rayobyte.com:8000)
# Proxy IP: 188.120.80.16, Fraud Score: 95
# Proxy IP: 83.137.124.10, Fraud Score: 82
