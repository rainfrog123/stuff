# %%
import requests

# Function to format proxy list from raw text
def format_proxy_list(proxy_string):
    proxy_lines = proxy_string.strip().split("\n")
    formatted_proxies = [line.strip() for line in proxy_lines]  # Removed extra double quotes
    return formatted_proxies

# Raw proxy list text (replace this with actual text from the website or file)
proxy_string = """
ee5498404_gmail_com:nimasile-country-QA-session-50c6b75d@la.residential.rayobyte.com:8000
ee5498404_gmail_com:nimasile-country-QA-session-8fce0242@la.residential.rayobyte.com:8000
ee5498404_gmail_com:nimasile-country-QA-session-6369c749@la.residential.rayobyte.com:8000
ee5498404_gmail_com:nimasile-country-QA-session-7ed2681b@la.residential.rayobyte.com:8000
ee5498404_gmail_com:nimasile-country-QA-session-17c485fe@la.residential.rayobyte.com:8000
ee5498404_gmail_com:nimasile-country-QA-session-9c0cbec6@la.residential.rayobyte.com:8000
ee5498404_gmail_com:nimasile-country-QA-session-976dbb1b@la.residential.rayobyte.com:8000
ee5498404_gmail_com:nimasile-country-QA-session-ef17def2@la.residential.rayobyte.com:8000
ee5498404_gmail_com:nimasile-country-QA-session-204b83a9@la.residential.rayobyte.com:8000
ee5498404_gmail_com:nimasile-country-QA-session-2cdbda1e@la.residential.rayobyte.com:8000

# 
"""

# Format and set proxy list
proxies = format_proxy_list(proxy_string)

# IPQualityScore API key
api_key = "FpWURHKy8cHf2p4vOiW43ldS5IKe5BNc"

# Function to get the fraud score from IPQualityScore API
def get_fraud_score(ip):
    url = f"https://ipqualityscore.com/api/json/ip/{api_key}/{ip}?strictness=3"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return data.get("fraud_score")
    else:
        print(f"Failed to retrieve fraud score for IP: {ip}")
        return None

# Function to test proxy and get the public IP using it
def test_proxy(proxy_url):
    proxy = {
        "http": f"http://{proxy_url}",
        "https": f"http://{proxy_url}",
    }
    try:
        # Get the public IP using the proxy
        response = requests.get("http://ipinfo.io/ip", proxies=proxy, timeout=10)
        if response.status_code == 200:
            ip = response.text.strip()
            fraud_score = get_fraud_score(ip)
            if fraud_score == 0:
                print(f"Proxy IP: {ip}, Fraud Score: {fraud_score} (Using Proxy: {proxy_url})")
            else:
                print(f"Proxy IP: {ip}, Fraud Score: {fraud_score}")
        else:
            print(f"Failed to fetch IP info using proxy {proxy_url}")
    except Exception as e:
        print(f"Proxy {proxy_url} failed. Error: {e}")

# Check each proxy
for proxy in proxies:
    test_proxy(proxy)

# %%
# curl https://ipqualityscore.com/api/json/ip/FpWURHKy8cHf2p4vOiW43ldS5IKe5BNc/131.117.177.58
