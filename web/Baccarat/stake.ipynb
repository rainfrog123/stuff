# %%
import secrets

def generate_realistic_baccarat_steps_secure(match_sequence):
    # Convert input string like 'pbpbt' to a list of outcomes
    outcome_mapping = {'p': 'Player', 'b': 'Banker', 't': 'Tie'}
    try:
        match_sequence = [outcome_mapping[char.lower()] for char in match_sequence]
    except KeyError:
        raise ValueError("Invalid input: Use 'p' for Player, 'b' for Banker, and 't' for Tie only.")

    # Define outcomes and their respective probabilities
    outcomes = ["Banker", "Player", "Tie"]
    probabilities = [45.86, 44.62, 9.52]  # Corresponding probabilities

    def weighted_choice(choices, weights):
        total = sum(weights)
        r = secrets.randbelow(int(total * 10000)) / 10000  # Cryptographically secure random number
        cumulative = 0
        for choice, weight in zip(choices, weights):
            cumulative += weight
            if r < cumulative:
                return choice
        return choices[-1]  # Fallback to last choice

    steps = []
    # Keep generating steps until the first part matches the specified sequence
    while True:
        steps = [weighted_choice(outcomes, probabilities) for _ in range(6)]  # Generate 6 random steps
        if steps[:len(match_sequence)] == match_sequence:  # Check if the initial part matches the sequence
            break  # Stop if match is found
    
    return steps

# Example usage: Define your sequence here
input_sequence = "pbtpbpbtp"  # You can replace 'pbpb' with any valid sequence including 't' for Tie
# Generate the next 6 Baccarat outcomes using cryptographically secure random generator
next_steps = generate_realistic_baccarat_steps_secure(input_sequence)
print(f"Generated sequence where first part matches '{input_sequence}':")
for i, step in enumerate(next_steps, start=1):
    print(f"Step {i}: {step}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 37
#      35 input_sequence = "pbtpbpbtp"  # You can replace 'pbpb' with any valid sequence including 't' for Tie
#      36 # Generate the next 6 Baccarat outcomes using cryptographically secure random generator
# ---> 37 next_steps = generate_realistic_baccarat_steps_secure(input_sequence)
#      38 print(f"Generated sequence where first part matches '{input_sequence}':")
#      39 for i, step in enumerate(next_steps, start=1):
#
# Cell In[69], line 28, in generate_realistic_baccarat_steps_secure(match_sequence)
#      26 # Keep generating steps until the first part matches the specified sequence
#      27 while True:
# ---> 28     steps = [weighted_choice(outcomes, probabilities) for _ in range(6)]  # Generate 6 random steps
# ...

# %%
import secrets

def generate_realistic_baccarat_steps_secure(match_sequence):
    # Ensure the match_sequence is exactly 12 characters long
    if len(match_sequence) != 12:
        raise ValueError("The match_sequence must be exactly 12 characters long.")
    
    # Convert input string like 'bptppppppbbt' to a list of outcomes
    outcome_mapping = {'p': 'Player', 'b': 'Banker', 't': 'Tie'}
    try:
        match_sequence = [outcome_mapping[char.lower()] for char in match_sequence]
    except KeyError:
        raise ValueError("Invalid input: Use 'p' for Player, 'b' for Banker, and 't' for Tie only.")

    # Define outcomes and their respective probabilities
    outcomes = ["Banker", "Player", "Tie"]
    probabilities = [45.86, 44.62, 9.52]  # Corresponding probabilities

    def weighted_choice(choices, weights):
        total = sum(weights)
        r = secrets.randbelow(int(total * 10000)) / 10000  # Cryptographically secure random number
        cumulative = 0
        for choice, weight in zip(choices, weights):
            cumulative += weight
            if r < cumulative:
                return choice
        return choices[-1]  # Fallback to last choice

    steps = []
    # Generate steps until the first 12 match the specified sequence
    while True:
        # Generate 13 random steps
        temp_steps = [weighted_choice(outcomes, probabilities) for _ in range(13)]
        # Check if the initial 12 parts match the sequence
        if temp_steps[:12] == match_sequence:
            steps = temp_steps
            break  # Stop if match is found
    
    return steps

# Define your exact sequence of 12 characters
input_sequence = "bbbpbbpbppbb"  # Ensure this is 12 characters

# Generate the next 13 Baccarat outcomes using cryptographically secure random generator
next_steps = generate_realistic_baccarat_steps_secure(input_sequence)
print(f"Generated sequence where first 12 values match the given pattern:")
for i, step in enumerate(next_steps, start=1):
    print(f"Step {i}: {step}")
# Out:
# Generated sequence where first 12 values match the given pattern:
# Step 1: Banker
# Step 2: Banker
# Step 3: Banker
# Step 4: Player
# Step 5: Banker
# Step 6: Banker
# Step 7: Player
# Step 8: Banker
# Step 9: Player
# Step 10: Player
# Step 11: Banker
# Step 12: Banker
# Step 13: Tie

# %%
import secrets

def generate_realistic_baccarat_steps_secure(match_sequence):
    # The number of steps is the length of match_sequence plus one
    total_steps = len(match_sequence) + 1
    
    # Convert input string to a list of outcomes
    outcome_mapping = {'p': 'Player', 'b': 'Banker', 't': 'Tie'}
    try:
        match_sequence = [outcome_mapping[char.lower()] for char in match_sequence]
    except KeyError:
        raise ValueError("Invalid input: Use 'p' for Player, 'b' for Banker, and 't' for Tie only.")

    # Define outcomes and their respective probabilities
    outcomes = ["Banker", "Player", "Tie"]
    probabilities = [45.86, 44.62, 9.52]  # Corresponding probabilities

    def weighted_choice(choices, weights):
        total = sum(weights)
        r = secrets.randbelow(int(total * 10000)) / 10000  # Cryptographically secure random number
        cumulative = 0
        for choice, weight in zip(choices, weights):
            cumulative += weight
            if r < cumulative:
                return choice
        return choices[-1]  # Fallback to last choice

    steps = []
    # Keep generating steps until the first len(match_sequence) match the specified sequence
    while True:
        # Generate random total_steps
        temp_steps = [weighted_choice(outcomes, probabilities) for _ in range(total_steps)]
        # Check if the initial len(match_sequence) parts match the sequence
        if temp_steps[:len(match_sequence)] == match_sequence:
            steps = temp_steps
            break  # Stop if match is found
    
    return steps

# Example usage: Define your sequence
input_sequence = "ppbtbbpptbp"  # The actual input length here is 12, so 13 steps will be generated

# Generate the next steps using cryptographically secure random generator
next_steps = generate_realistic_baccarat_steps_secure(input_sequence)
print(f"Generated sequence where first {len(input_sequence)} values match the given pattern:")
for i, step in enumerate(next_steps, start=1):
    print(f"Step {i}: {step}")
# Out:
# Generated sequence where first 11 values match the given pattern:
# Step 1: Player
# Step 2: Player
# Step 3: Banker
# Step 4: Tie
# Step 5: Banker
# Step 6: Banker
# Step 7: Player
# Step 8: Player
# Step 9: Tie
# Step 10: Banker
# Step 11: Player
# Step 12: Tie
